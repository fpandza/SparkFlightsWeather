# %%
# %sql
select * from

# %%
# %sql
create table conditions_minmax as
select * from conditions_pcts
where pct != -1 and cnt_total > 2000
order by pct asc
limit 5
;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
insert into conditions_minmax
select * from conditions_pcts
where pct != -1 and cnt_total > 2000
order by pct desc
limit 5
;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
df_conditions = spark.sql("select * from conditions_minmax");
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df_conditions.select("condition","pct").orderBy("pct"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>condition</th><th>pct</th></tr></thead><tbody><tr><td>0000000</td><td>0.33</td></tr><tr><td>1000000</td><td>0.35</td></tr><tr><td>0010001</td><td>0.36</td></tr><tr><td>0100000</td><td>0.37</td></tr><tr><td>0010000</td><td>0.38</td></tr><tr><td>1111010</td><td>0.56</td></tr><tr><td>0111010</td><td>0.56</td></tr><tr><td>1110110</td><td>0.56</td></tr><tr><td>0101000</td><td>0.57</td></tr><tr><td>1010011</td><td>0.59</td></tr></tbody></table></div>

# %%
# %sql
--show tables;
select count(*) from conditions_pcts_delay;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>0</td></tr></tbody></table></div>

# %%
df_conditions_delays = spark.sql("select * from conditions_delay_minmax");
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df_conditions_delays.select("condition","delay_index").orderBy("delay_index"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>condition</th><th>delay_index</th></tr></thead><tbody><tr><td>0010001</td><td>8.64</td></tr><tr><td>0000000</td><td>8.91</td></tr><tr><td>1000000</td><td>10.15</td></tr><tr><td>0100000</td><td>11.47</td></tr><tr><td>0010000</td><td>12.16</td></tr><tr><td>1111000</td><td>30.8</td></tr><tr><td>1110010</td><td>31.9</td></tr><tr><td>1011110</td><td>33.48</td></tr><tr><td>1110110</td><td>33.6</td></tr><tr><td>1111010</td><td>34.16</td></tr></tbody></table></div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">NameError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-1666142400569862&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# ...
